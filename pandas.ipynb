# %%
import numpy as np
a = np.array([1, 2, 3])
b = a[np.newaxis,:]
print(b)
# Out:
# [[1 2 3]]

# %%
import pandas as pd
import numpy as np
array = np.array(["blue", "yellow", "pink", "purple"]) # get the array
series1 = pd.Series(array)  #create the series from the array
print(series1)
# Out:
# 0      blue
# 1    yellow
# 2      pink
# 3    purple
# dtype: object

# %%
list = [19, 175, 41, 22]
series2 = pd.Series(list) #create the series from the list
print(series2)
# Out:
# 0          19
# 1    17999885
# 2          41
# 3          22
# dtype: int64

# %%
import pandas as pd
color=["pink", "white", "black", "blue"]
occurence = [20, 15, 6, 43]
S=pd.Series(occurence, index=color)
print(S)
# Out:
# pink     20
# white    15
# black     6
# blue     43
# dtype: int64

# %%
import pandas as pd
color=["pink", "white", "black", "blue"]
S1=pd.Series([20, 15, 6, 43], index=color)
S2=pd.Series([3, 22, 9, 10], index=color)
print(S1+S2)
# Out:
# pink     23
# white    37
# black    15
# blue     53
# dtype: int64

# %%
import pandas as pd
list = [['Jack', 34, 'Paris'], ['Thomas', 30, 'Roma'], 
       ['Alexandre', 16, 'New York']] 
df = pd.DataFrame(list, columns =['name', 'age', 'city'])
print(df)
# Out:
#         name  age      city
# 0       Jack   34     Paris
# 1     Thomas   30      Roma
# 2  Alexandre   16  New York

# %%
dictionary  = { 'name' : ['Jack', 'Thomas', 'Alexandre'],
    'age' : [34, 30, 16],
    'city' : ['Paris', 'Roma', 'New York']}

df = pd.DataFrame(dictionary)
print(df)
# Out:
#         name  age      city
# 0       Jack   34     Paris
# 1     Thomas   30      Roma
# 2  Alexandre   16  New York

# %%
import numpy as np
import pandas as pd
my_numpy_array=np.random.randn(3,4)
l=['a,','b','c','d']

df=pd.DataFrame(my_numpy_array,columns=l)
print(df)
# Out:
#          a,         b         c         d
# 0 -1.516714  1.587351  0.547630 -0.507243
# 1 -0.114844 -0.559900  0.962473 -0.672234
# 2  0.585680 -0.130500  0.382778  1.646637

# %%
# DataFrame using arrays.
import pandas as pd
  
# initialize data of lists.
data = {'Name': ['Tom', 'Jack', 'nick', 'juli'],
        'marks': [99, 98, 95, 90]}
  
# Creates pandas DataFrame.
df = pd.DataFrame(data, index=['rank1',
                               'rank2',
                               'rank3',
                               'rank4'])
  
# print the data
df
# Out:
#        Name  marks
# rank1   Tom     99
# rank2  Jack     98
# rank3  nick     95
# rank4  juli     90

# %%
import pandas as pd
  
# Initialize data to series.
d =  pd.Series([10, 20, 30, 40])
# creates Dataframe.
df = pd.DataFrame(d)
  
# print the data.
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40

# %%
import pandas as pd
df=pd.read_csv("df.csv")
df
# Out:
#    Unnamed: 0       name  age      city
# 0           0       Jack   34     Paris
# 1           1     Thomas   30      Roma
# 2           2  Alexandre   16  New York

# %%
dictionary  = { 'name' : ['Jack', 'Thomas', 'Alexandre'],
    'age' : [34, 30, 16],
    'city' : ['Paris', 'Roma', 'New York']}

df = pd.DataFrame(dictionary)
df.to_csv('df.csv')
dfs=pd.read_csv("df.csv")
dfs.head()
dfs.tail()
# Out:
#    Unnamed: 0       name  age      city
# 0           0       Jack   34     Paris
# 1           1     Thomas   30      Roma
# 2           2  Alexandre   16  New York

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
     index=['cobra', 'viper', 'sidewinder'],
     columns=['max_speed', 'shield'])

df.iloc[:, 1:3]
# Out:
#             shield
# cobra            2
# viper            5
# sidewinder       8

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
     index=['cobra', 'viper', 'sidewinder'],
     columns=['max_speed', 'shield'])

df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
df = pd.DataFrame(np.arange(9).reshape(3, 3),
                  columns=['A', 'B', 'C'])
df.drop(1,axis=0)
# Out:
#    A  B  C
# 0  0  1  2
# 2  6  7  8

# %%
'''
Objective
Write a Pandas program to create and display a DataFrame from the following dictionary data with index labels.

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
'''

# %%
'''
1 Print the three first rows using the head() method.

'''
import pandas as pd
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
'''
2 Delete rows with Nan values.
'''
import pandas as pd
import numpy as np

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
print(df.dropna(axis=0))
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
'''
3 Extract the 'name' and 'score' columns from the DataFrame.
'''
import pandas as pd
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
df[["name","score"]]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
'''
4 Write a Pandas program to append a new row 'k' to the DataFrame with these values
(name: "Suresh", score: 15.5, attempts: 1, qualify: "yes").
'''
import pandas as pd
'''
loc methode x
new_row = {'Name':'Jane', 'Age':30, 'City':'New York'}
df.loc[len(df)] = new_row

concat methode
new_row = pd.DataFrame({'Name':['Jane'], 'Age':[30], 'City':['New York']})
df = pd.concat([df, new_row], ignore_index=True)

'''
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)

new_row = {'name':'Jane', 'score':30, 'attempts':3,'qualify':'no'}
df = df.append(new_row, ignore_index=True)
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17368\1682948568.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
#          name  score  attempts qualify
# 0   Anastasia   12.5         1     yes
# 1        Dima    9.0         3      no
# 2   Katherine   16.5         2     yes
# 3       James    NaN         3      no
# 4       Emily    9.0         2      no
# 5     Michael   20.0         3     yes
# 6     Matthew   14.5         1     yes
# 7       Laura    NaN         1      no
# 8       Kevin    8.0         2      no
# 9       Jonas   19.0         1     yes
# 10       Jane   30.0         3      no

# %%
'''
5 Write a Pandas program to delete the 'attempts' column from the DataFrame.
'''
import pandas as pd
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
#df.drop('attempts',axis=1,inplace=True)
#del df['attempts']
df.pop('attempts')
df
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# d      James    NaN      no
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# h      Laura    NaN      no
# i      Kevin    8.0      no
# j      Jonas   19.0     yes

# %%
'''
6 Add a new column "Success": if the score is higher than 10 we will have 1, else we will have 0.
'''
import pandas as pd
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
df['Success']=[1 if i>10 else 0 for i in df['score']]
df

'''
df['Success'] = df['score'].apply(lambda x : 1 if x > 10 else 0)

or 
df['Success'] = np.where(df['score'] > 10, 1, 0)

'''
# Out:
#         name  score  attempts qualify  Success
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1
# d      James    NaN         3      no        0
# e      Emily    9.0         2      no        0
# f    Michael   20.0         3     yes        1
# g    Matthew   14.5         1     yes        1
# h      Laura    NaN         1      no        0
# i      Kevin    8.0         2      no        0
# j      Jonas   19.0         1     yes        1

# %%
'''
7 After executing the final DataFrame, export it into a CSV file named "my_data".
'''
import pandas as pd

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index=labels)
df['Success']=[1 if i>10 else 0 for i in df['score']]

df.to_csv('my_data.csv', index=False)
df=pd.read_csv("my_data.csv")
df
# Out:
#         name  score  attempts qualify  Success
# 0  Anastasia   12.5         1     yes        1
# 1       Dima    9.0         3      no        0
# 2  Katherine   16.5         2     yes        1
# 3      James    NaN         3      no        0
# 4      Emily    9.0         2      no        0
# 5    Michael   20.0         3     yes        1
# 6    Matthew   14.5         1     yes        1
# 7      Laura    NaN         1      no        0
# 8      Kevin    8.0         2      no        0
# 9      Jonas   19.0         1     yes        1
